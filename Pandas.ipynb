# %%
import pandas as pd
import numpy as np

# %%
##series dataframe
s = pd.Series([1,2,3,4,5,6,np.nan,8,9,10])

# %%
s
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float64

# %%
d = pd.date_range('20200301',periods=10)

# %%
d
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
#Creating data Frame
df = pd.DataFrame(np.random.randn(10,4),index=d,columns=['A','B','C','D'])

# %%
df
# Out:
#                    A         B         C         D
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089
# 2020-03-02 -0.770644  1.463893  0.850709 -2.290959
# 2020-03-03 -0.998085 -0.157135  0.099309 -1.949805
# 2020-03-04 -0.345791  0.763163 -0.052268 -0.031637
# 2020-03-05 -0.830381  1.222556 -0.435222  0.501201
# 2020-03-06 -1.696575 -1.416397 -0.251425 -0.927159
# 2020-03-07  0.244252 -1.167324 -0.182712 -1.047321
# 2020-03-08  0.268892 -1.619663 -0.363277  1.735454
# 2020-03-09  1.177939  0.579130 -0.337970 -0.534269
# 2020-03-10 -2.262863 -0.840955  0.230598  1.250168

# %%
#Getting Few number rows
df.loc['20200301':'20200306',['D','C']]
# Out:
#                    D         C
# 2020-03-01  0.202089 -0.790121
# 2020-03-02 -2.290959  0.850709
# 2020-03-03 -1.949805  0.099309
# 2020-03-04 -0.031637 -0.052268
# 2020-03-05  0.501201 -0.435222
# 2020-03-06 -0.927159 -0.251425

# %%
#Exact value
df.at[d[0],'C']
# Out:
# np.float64(-0.7901212181458527)

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2020-03-04 -0.345791  0.763163
# 2020-03-05 -0.830381  1.222556

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2020-03-07  0.244252 -1.167324 -0.182712 -1.047321
# 2020-03-08  0.268892 -1.619663 -0.363277  1.735454
# 2020-03-09  1.177939  0.579130 -0.337970 -0.534269

# %%
#Handling missing value
#1.Reindexind
df2=df.reindex(index=d[0:4], columns=list(df.columns)+ ['E'])

# %%
df2
# Out:
#                    A         B         C         D   E
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089 NaN
# 2020-03-02 -0.770644  1.463893  0.850709 -2.290959 NaN
# 2020-03-03 -0.998085 -0.157135  0.099309 -1.949805 NaN
# 2020-03-04 -0.345791  0.763163 -0.052268 -0.031637 NaN

# %%
df2.loc[d[0]:d[1], 'E']=1

# %%
df2
# Out:
#                    A         B         C         D    E
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089  1.0
# 2020-03-02 -0.770644  1.463893  0.850709 -2.290959  1.0
# 2020-03-03 -0.998085 -0.157135  0.099309 -1.949805  NaN
# 2020-03-04 -0.345791  0.763163 -0.052268 -0.031637  NaN

# %%
#Check null value
df2.isnull()
# Out:
#                 A      B      C      D      E
# 2020-03-01  False  False  False  False  False
# 2020-03-02  False  False  False  False  False
# 2020-03-03  False  False  False  False   True
# 2020-03-04  False  False  False  False   True

# %%
#Drop null value
df2.dropna()
# Out:
#                    A         B         C         D    E
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089  1.0
# 2020-03-02 -0.770644  1.463893  0.850709 -2.290959  1.0

# %%
df2.fillna(value=2)
# Out:
#                    A         B         C         D    E
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089  1.0
# 2020-03-02 -0.770644  1.463893  0.850709 -2.290959  1.0
# 2020-03-03 -0.998085 -0.157135  0.099309 -1.949805  2.0
# 2020-03-04 -0.345791  0.763163 -0.052268 -0.031637  2.0

# %%
#Pandas Operation 
#1.Descriptive Statistic Operations(Mean)
#2.Applying Function To The Data 
#3.String Processing Operation
#4.Histogramming

# %%
#1.Mean values
df.mean(1)
# Out:
# 2020-03-01   -0.387264
# 2020-03-02   -0.186750
# 2020-03-03   -0.751429
# 2020-03-04    0.083367
# 2020-03-05    0.114539
# 2020-03-06   -1.072889
# 2020-03-07   -0.538276
# 2020-03-08    0.005352
# 2020-03-09    0.221207
# 2020-03-10   -0.405763
# Freq: D, dtype: float64

# %%
s = pd.Series([1,2,3,np.nan,4,5,6,7,8,9],index=d).shift(2)

# %%
s
# Out:
# 2020-03-01    NaN
# 2020-03-02    NaN
# 2020-03-03    1.0
# 2020-03-04    2.0
# 2020-03-05    3.0
# 2020-03-06    NaN
# 2020-03-07    4.0
# 2020-03-08    5.0
# 2020-03-09    6.0
# 2020-03-10    7.0
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2020-03-01       NaN       NaN       NaN       NaN
# 2020-03-02       NaN       NaN       NaN       NaN
# 2020-03-03 -1.998085 -1.157135 -0.900691 -2.949805
# 2020-03-04 -2.345791 -1.236837 -2.052268 -2.031637
# 2020-03-05 -3.830381 -1.777444 -3.435222 -2.498799
# 2020-03-06       NaN       NaN       NaN       NaN
# 2020-03-07 -3.755748 -5.167324 -4.182712 -5.047321
# 2020-03-08 -4.731108 -6.619663 -5.363277 -3.264546
# 2020-03-09 -4.822061 -5.420870 -6.337970 -6.534269
# 2020-03-10 -9.262863 -7.840955 -6.769402 -5.749832

# %%
#   Apply Function
#Cumsum will fill
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2020-03-01 -1.070784  0.109760 -0.790121  0.202089
# 2020-03-02 -1.841427  1.573653  0.060588 -2.088870
# 2020-03-03 -2.839512  1.416517  0.159897 -4.038675
# 2020-03-04 -3.185303  2.179681  0.107629 -4.070311
# 2020-03-05 -4.015684  3.402237 -0.327592 -3.569110
# 2020-03-06 -5.712259  1.985839 -0.579017 -4.496269
# 2020-03-07 -5.468007  0.818515 -0.761729 -5.543590
# 2020-03-08 -5.199115 -0.801148 -1.125006 -3.808135
# 2020-03-09 -4.021176 -0.222018 -1.462976 -4.342404
# 2020-03-10 -6.284038 -1.062973 -1.232378 -3.092236

# %%
#Lambda
df.apply(lambda x: x.max()-x.min())
# Out:
# A    3.440802
# B    3.083556
# C    1.640831
# D    4.026413
# dtype: float64

# %%
s.value_counts()
# Out:
# 1.0    1
# 2.0    1
# 3.0    1
# 4.0    1
# 5.0    1
# 6.0    1
# 7.0    1
# Name: count, dtype: int64

# %%
s =pd.Series(['edureka','python','jupyter',np.nan,'football','world'])

# %%
s
# Out:
# 0     edureka
# 1      python
# 2     jupyter
# 3         NaN
# 4    football
# 5       world
# dtype: object

# %%
s.str.lower()
# Out:
# 0     edureka
# 1      python
# 2     jupyter
# 3         NaN
# 4    football
# 5       world
# dtype: object

# %%
s.str.upper()
# Out:
# 0     EDUREKA
# 1      PYTHON
# 2     JUPYTER
# 3         NaN
# 4    FOOTBALL
# 5       WORLD
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0  1.065255  1.343100 -0.181969  0.701368
# 1 -0.345663  1.399529  1.006689 -0.771176
# 2  0.886187  0.273642 -0.126028  0.291520
# 3 -0.050638  1.298270  1.153766  1.583044
# 4 -0.801081 -1.100854  0.721577 -1.413573
# 5  0.103387  0.726518 -1.213924 -0.050570
# 6 -0.111342 -0.408665 -0.135859  1.419113
# 7 -0.872305  1.549964  2.262707 -0.357467
# 8 -1.039509 -0.783419 -0.047669  0.955208
# 9 -1.611592  1.439515 -0.113024  0.381924

# %%
df2 = [df[:3],df[3:7],df[7:]]

# %%
df2
# Out:
# [          0         1         2         3
#  0  1.065255  1.343100 -0.181969  0.701368
#  1 -0.345663  1.399529  1.006689 -0.771176
#  2  0.886187  0.273642 -0.126028  0.291520,
#            0         1         2         3
#  3 -0.050638  1.298270  1.153766  1.583044
#  4 -0.801081 -1.100854  0.721577 -1.413573
#  5  0.103387  0.726518 -1.213924 -0.050570
#  6 -0.111342 -0.408665 -0.135859  1.419113,
#            0         1         2         3
#  7 -0.872305  1.549964  2.262707 -0.357467
#  8 -1.039509 -0.783419 -0.047669  0.955208
#  9 -1.611592  1.439515 -0.113024  0.381924]

# %%
#Concatination
pd.concat(df2)
# Out:
#           0         1         2         3
# 0  1.065255  1.343100 -0.181969  0.701368
# 1 -0.345663  1.399529  1.006689 -0.771176
# 2  0.886187  0.273642 -0.126028  0.291520
# 3 -0.050638  1.298270  1.153766  1.583044
# 4 -0.801081 -1.100854  0.721577 -1.413573
# 5  0.103387  0.726518 -1.213924 -0.050570
# 6 -0.111342 -0.408665 -0.135859  1.419113
# 7 -0.872305  1.549964  2.262707 -0.357467
# 8 -1.039509 -0.783419 -0.047669  0.955208
# 9 -1.611592  1.439515 -0.113024  0.381924

# %%
#Join Function
left = pd.DataFrame({'A':[1,2],'B':[3,4]})

# %%
right = pd.DataFrame({'C':[3,2],'D':[4,5]})

# %%
left
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
right
# Out:
#    C  D
# 0  3  4
# 1  2  5

# %%
#Grouping Data Structure
df
# Out:
#           0         1         2         3
# 0  1.065255  1.343100 -0.181969  0.701368
# 1 -0.345663  1.399529  1.006689 -0.771176
# 2  0.886187  0.273642 -0.126028  0.291520
# 3 -0.050638  1.298270  1.153766  1.583044
# 4 -0.801081 -1.100854  0.721577 -1.413573
# 5  0.103387  0.726518 -1.213924 -0.050570
# 6 -0.111342 -0.408665 -0.135859  1.419113
# 7 -0.872305  1.549964  2.262707 -0.357467
# 8 -1.039509 -0.783419 -0.047669  0.955208
# 9 -1.611592  1.439515 -0.113024  0.381924

# %%
df.groupby(2).sum()
# Out:
#                   0         1         3
# 2
# -1.213924  0.103387  0.726518 -0.050570
# -0.181969  1.065255  1.343100  0.701368
# -0.135859 -0.111342 -0.408665  1.419113
# -0.126028  0.886187  0.273642  0.291520
# -0.113024 -1.611592  1.439515  0.381924
# -0.047669 -1.039509 -0.783419  0.955208
#  0.721577 -0.801081 -1.100854 -1.413573
#  1.006689 -0.345663  1.399529 -0.771176
#  1.153766 -0.050638  1.298270  1.583044
#  2.262707 -0.872305  1.549964 -0.357467

# %%
#Stack Pivot Table
my_tuple = list(zip(*[[1,2,3,4,5],[11,12,13,14,15,6,7,8,9]]))

# %%
index = pd.MultiIndex.from_tuples(my_tuple,names=['First','Second'])

# %%
index
# Out:
# MultiIndex([(1, 11),
#             (2, 12),
#             (3, 13),
#             (4, 14),
#             (5, 15)],
#            names=['First', 'Second'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#           0         1         2         3
# 0  1.065255  1.343100 -0.181969  0.701368
# 1 -0.345663  1.399529  1.006689 -0.771176
# 2  0.886187  0.273642 -0.126028  0.291520
# 3 -0.050638  1.298270  1.153766  1.583044

# %%
df2.stack()
# Out:
# 0  0    1.065255
#    1    1.343100
#    2   -0.181969
#    3    0.701368
# 1  0   -0.345663
#    1    1.399529
#    2    1.006689
#    3   -0.771176
# 2  0    0.886187
#    1    0.273642
#    2   -0.126028
#    3    0.291520
# 3  0   -0.050638
#    1    1.298270
#    2    1.153766
#    3    1.583044
# dtype: float64

# %%
df2.unstack()
# Out:
# 0  0    1.065255
#    1   -0.345663
#    2    0.886187
#    3   -0.050638
# 1  0    1.343100
#    1    1.399529
#    2    0.273642
#    3    1.298270
# 2  0   -0.181969
#    1    1.006689
#    2   -0.126028
#    3    1.153766
# 3  0    0.701368
#    1   -0.771176
#    2    0.291520
#    3    1.583044
# dtype: float64

# %%
#Time Series and categorical
##Padas has simple,power full and efficient functionality for performing operations during frequency conversion.
dates =pd.date_range('20200301',periods = 100,freq='S')
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_18172\2077044441.py:3: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   dates =pd.date_range('20200301',periods = 100,freq='S')

# %%
dates
# Out:
# DatetimeIndex(['2020-03-01 00:00:00', '2020-03-01 00:00:01',
#                '2020-03-01 00:00:02', '2020-03-01 00:00:03',
#                '2020-03-01 00:00:04', '2020-03-01 00:00:05',
#                '2020-03-01 00:00:06', '2020-03-01 00:00:07',
#                '2020-03-01 00:00:08', '2020-03-01 00:00:09',
#                '2020-03-01 00:00:10', '2020-03-01 00:00:11',
#                '2020-03-01 00:00:12', '2020-03-01 00:00:13',
#                '2020-03-01 00:00:14', '2020-03-01 00:00:15',
#                '2020-03-01 00:00:16', '2020-03-01 00:00:17',
#                '2020-03-01 00:00:18', '2020-03-01 00:00:19',
#                '2020-03-01 00:00:20', '2020-03-01 00:00:21',
#                '2020-03-01 00:00:22', '2020-03-01 00:00:23',
#                '2020-03-01 00:00:24', '2020-03-01 00:00:25',
#                '2020-03-01 00:00:26', '2020-03-01 00:00:27',
#                '2020-03-01 00:00:28', '2020-03-01 00:00:29',
# ...

# %%
ts =pd.Series(np.random.randint(0,500,len(dates)),dates)

# %%
ts
# Out:
# 2020-03-01 00:00:00    253
# 2020-03-01 00:00:01     96
# 2020-03-01 00:00:02    351
# 2020-03-01 00:00:03    323
# 2020-03-01 00:00:04     74
#                       ...
# 2020-03-01 00:01:35    180
# 2020-03-01 00:01:36     40
# 2020-03-01 00:01:37    319
# 2020-03-01 00:01:38    424
# 2020-03-01 00:01:39    249
# Freq: s, Length: 100, dtype: int32
